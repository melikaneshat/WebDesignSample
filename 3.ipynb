# %%
# importting Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as wr
wr.filterwarnings('ignore')
# loading and reading dataset
df = pd.read_csv("crypto-markets.csv")
print(df.head())
# Out:
#       slug symbol     name        date  ranknow    open    high     low  \
# 0  bitcoin    BTC  Bitcoin  2013-04-28        1  135.30  135.98  132.10
# 1  bitcoin    BTC  Bitcoin  2013-04-29        1  134.44  147.49  134.00
# 2  bitcoin    BTC  Bitcoin  2013-04-30        1  144.00  146.93  134.05
# 3  bitcoin    BTC  Bitcoin  2013-05-01        1  139.00  139.89  107.72
# 4  bitcoin    BTC  Bitcoin  2013-05-02        1  116.38  125.60   92.28
#
#     close  volume        market  close_ratio  spread
# 0  134.21     0.0  1.488567e+09       0.5438    3.88
# 1  144.54     0.0  1.603769e+09       0.7813   13.49
# 2  139.00     0.0  1.542813e+09       0.3843   12.88
# 3  116.99     0.0  1.298955e+09       0.2882   32.17
# 4  105.21     0.0  1.168517e+09       0.3881   33.32

# %%
# shape of the data
df.shape
# Out:
# (942297, 13)

# %%
#data information 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 942297 entries, 0 to 942296
# Data columns (total 13 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   slug         942297 non-null  object
#  1   symbol       942297 non-null  object
#  2   name         942297 non-null  object
#  3   date         942297 non-null  object
#  4   ranknow      942297 non-null  int64
#  5   open         942297 non-null  float64
#  6   high         942297 non-null  float64
#  7   low          942297 non-null  float64
#  8   close        942297 non-null  float64
#  9   volume       942297 non-null  float64
#  10  market       942297 non-null  float64
#  11  close_ratio  942297 non-null  float64
#  12  spread       942297 non-null  float64
# dtypes: float64(8), int64(1), object(4)
# memory usage: 93.5+ MB

# %%
# describing the data
df.describe()
# Out:
#              ranknow          open          high           low         close  \
# count  942297.000000  9.422970e+05  9.422970e+05  9.422970e+05  9.422970e+05
# mean     1000.170608  3.483522e+02  4.085930e+02  2.962526e+02  3.461018e+02
# std       587.575283  1.318436e+04  1.616386e+04  1.092931e+04  1.309822e+04
# min         1.000000  2.500000e-09  3.200000e-09  2.500000e-10  2.000000e-10
# 25%       465.000000  2.321000e-03  2.628000e-03  2.044000e-03  2.314000e-03
# 50%      1072.000000  2.398300e-02  2.680200e-02  2.143700e-02  2.389200e-02
# 75%      1484.000000  2.268600e-01  2.508940e-01  2.043910e-01  2.259340e-01
# max      2072.000000  2.298390e+06  2.926100e+06  2.030590e+06  2.300740e+06
#
#              volume        market    close_ratio        spread
# count  9.422970e+05  9.422970e+05  942297.000000  9.422970e+05
# mean   8.720383e+06  1.725060e+08       0.459499  1.123400e+02
# std    1.839802e+08  3.575590e+09       0.326160  6.783713e+03
# ...

# %%
#column to list 
df.columns.tolist()
# Out:
# ['slug',
#  'symbol',
#  'name',
#  'date',
#  'ranknow',
#  'open',
#  'high',
#  'low',
#  'close',
#  'volume',
#  'market',
#  'close_ratio',
#  'spread']

# %%
# check for missing values:
df.isnull().sum()
# Out:
# slug           0
# symbol         0
# name           0
# date           0
# ranknow        0
# open           0
# high           0
# low            0
# close          0
# volume         0
# market         0
# close_ratio    0
# spread         0
# dtype: int64

# %%
#checking duplicate values 
df.nunique()
# Out:
# slug             2071
# symbol           2005
# name             2071
# date             2043
# ranknow          2068
# open           266140
# high           269676
# low            263008
# close          265887
# volume         300528
# market         660996
# close_ratio     10022
# spread          12454
# dtype: int64

# %%
# Assuming 'df' is your DataFrame
quality_counts = df['slug'].value_counts()

# Using Matplotlib to create a count plot
plt.figure(figsize=(8, 6))
plt.bar(quality_counts.index, quality_counts, color='red')
plt.title('Count Plot of Quality')
plt.xlabel('slug')
plt.ylabel('Count')
plt.show()

# %%
# Assuming 'df' is your DataFrame
quality_counts = df['symbol'].value_counts()

# Using Matplotlib to create a count plot
plt.figure(figsize=(8, 6))
plt.bar(quality_counts.index, quality_counts, color='red')
plt.title('Count Plot of Quality')
plt.xlabel('symbol')
plt.ylabel('Count')
plt.show()

# %%
# Assuming 'df' is your DataFrame
quality_counts = df['name'].value_counts()

# Using Matplotlib to create a count plot
plt.figure(figsize=(8, 6))
plt.bar(quality_counts.index, quality_counts, color='red')
plt.title('Count Plot of Quality')
plt.xlabel('name')
plt.ylabel('Count')
plt.show()

# %%
# Assuming 'df' is your DataFrame
quality_counts = df['date'].value_counts()

# Using Matplotlib to create a count plot
plt.figure(figsize=(8, 6))
plt.bar(quality_counts.index, quality_counts, color='red')
plt.title('Count Plot of Quality')
plt.xlabel('date')
plt.ylabel('Count')
plt.show()

# %%
# Assuming 'df' is your DataFrame
quality_counts = df['market'].value_counts()

# Using Matplotlib to create a count plot
plt.figure(figsize=(8, 6))
plt.bar(quality_counts.index, quality_counts, color='red')
plt.title('Count Plot of Quality')
plt.xlabel('market')
plt.ylabel('Count')
plt.show()

# %%
# Assuming 'df' is your DataFrame
quality_counts = df['close_ratio'].value_counts()

# Using Matplotlib to create a count plot
plt.figure(figsize=(8, 6))
plt.bar(quality_counts.index, quality_counts, color='red')
plt.title('Count Plot of Quality')
plt.xlabel('close_ratio')
plt.ylabel('Count')
plt.show()

# %%
# Assuming 'df' is your DataFrame
quality_counts = df['spread'].value_counts()

# Using Matplotlib to create a count plot
plt.figure(figsize=(8, 6))
plt.bar(quality_counts.index, quality_counts, color='red')
plt.title('Count Plot of Quality')
plt.xlabel('spread')
plt.ylabel('Count')
plt.show()

# %%
# importing pandas library 
import pandas as pd 
# importing matplotlib library 
import matplotlib.pyplot as plt
open_counts = df['open'].value_counts()
close_counts = df['close'].value_counts()
# plotting a line graph 
print("Line graph: ") 
plt.plot(df["open"], df["close"]) 
plt.show() 
  
# plotting a scatter plot 
print("Scatter Plot:  ") 
plt.scatter(df["open"], df["close"]) 
plt.show()
# Out:
# Line graph:
# Scatter Plot:

# %%
# importing matplotlib library 
import matplotlib.pyplot as plt
open_counts = df['low'].value_counts()
close_counts = df['high'].value_counts()
# plotting a line graph 
print("Line graph: ") 
plt.plot(df["low"], df["high"]) 
plt.show() 
  
# plotting a scatter plot 
print("Scatter Plot:  ") 
plt.scatter(df["low"], df["high"]) 
plt.show()
# Out:
# Line graph:
# Scatter Plot:

# %%
# importing matplotlib library 
import matplotlib.pyplot as plt
open_counts = df['low'].value_counts()
# plotting a line graph 
print("Line graph: ") 
plt.plot(df["low"] 
plt.show() 
  
# plotting a scatter plot 
print("Scatter Plot:  ") 
plt.scatter(df["low"]) 
plt.show()
# Out:
#   File "C:\Users\m.neshati\AppData\Local\Temp\ipykernel_23400\99322784.py", line 7
#     plt.show()
#     ^
# SyntaxError: invalid syntax

# %%
# importing matplotlib library 
import matplotlib.pyplot as plt
open_counts = df['low'].value_counts()
close_counts = df['high'].value_counts()
# plotting a line graph 
print("Line graph: ") 
plt.plot(df["low"], df["high"]) 
plt.show() 
  
# plotting a scatter plot 
print("Scatter Plot:  ") 
plt.scatter(df["low"], df["high"]) 
plt.show()
# Out:
# Line graph:
# Scatter Plot:

# %%
df.nunique()
# Out:
# slug             2071
# symbol           2005
# name             2071
# date             2043
# ranknow          2068
# open           266140
# high           269676
# low            263008
# close          265887
# volume         300528
# market         660996
# close_ratio     10022
# spread          12454
# dtype: int64

# %%
df = pd.DataFrame(data = np.random.random(size=(4,13)), columns = ['slug','symbol','name','date','ranknow','open','high','low','close','volume','market','close_ratio','spread'])
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x="variable", y="value", data=pd.melt(df))
# Out:
# <AxesSubplot:xlabel='variable', ylabel='value'>

# %%
import numpy as np; np.random.seed(42)
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame(data = np.random.random(size=(4,13)), columns = ['slug','symbol','name','date','ranknow','open','high','low','close','volume','market','close_ratio','spread'])

df.plot(kind='box')
plt.show()

# %%
lines = df.plot.line(x='close', y='open')

# %%
lines = df.plot.line(x='low', y='high')

# %%
import matplotlib.pyplot as plt
import numpy as np


open_counts = df['low'].value_counts()
close_counts = df['high'].value_counts()
plt.plot(x, y)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Any suitable title")
plt.show()  # show first chart

# The figure() function helps in creating a
# new figure that can hold a new chart in it.
plt.figure()
x1 = [2, 4, 6, 8]
y1 = [3, 5, 7, 9]
plt.plot(x1, y1, '-.')

# Show another chart with '-' dotted line
plt.show()

# %%
lines = df.plot.line(x='low', y='value')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'value'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

open_counts = df['low'].value_counts()
close_counts = df['high'].value_counts()

# first plot with X and Y data
plt.plot(open_counts, close_counts)



# second plot with x1 and y1 data
plt.plot(open_counts, close_counts, '-.')

plt.xlabel("open_counts")
plt.ylabel("close_counts")
plt.title('multiple plots')
plt.show()

# %%
df = pd.DataFrame({
'low':df["low"],
   'high':df["high"]
lines = df.plot.line()
# Out:
#   File "C:\Users\m.neshati\AppData\Local\Temp\ipykernel_23400\1296936590.py", line 4
#     lines = df.plot.line()
#     ^
# SyntaxError: invalid syntax

# %%
df = pd.DataFrame({
'x'='low', 'y'='high'
lines = df.plot.line()
# Out:
#   File "C:\Users\m.neshati\AppData\Local\Temp\ipykernel_23400\2667395794.py", line 2
#     'x'='low', 'y'='high'
#        ^
# SyntaxError: invalid syntax
